# %%
import cv2
import numpy as np
import dlib
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
img_path = '../1.jpeg'
shape_predictor_path = 'shape_predictor_68_face_landmarks.dat'

# %%
# detects the whole face
detector = dlib.get_frontal_face_detector()

# detects face landmarks
predictor = dlib.shape_predictor(shape_predictor_path)

# %%
img = cv2.imread('1.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
os.listdir(os.getcwd())
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '1.jpeg',
#  '1.jpg',
#  'CNN.ipynb',
#  'Face_Transfer.ipynb',
#  'h.jpg',
#  'haarcascade_eye.xml',
#  'haarcascade_frontalface_default.xml',
#  'haarcascade_smile.xml',
#  'introductory.ipynb',
#  'landmarks positions.png',
#  'README.md',
#  'shape_predictor_68_face_landmarks.dat',
#  'test notebook.ipynb',
#  'test1.jpg',
#  'Training_Inference.ipynb',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
#detects all the faces 
faces = detector(img)
len(faces)
# Out:
# 1

# %%
# gets landmarks for face
for face in faces:
    landmarks = predictor(img, face)

# %%
# to view landmarks
for n in range(68):
    x = landmarks.part(n).x
    y = landmarks.part(n).y
    cv2.putText(img, str(n), (x,y), cv2.FONT_HERSHEY_SIMPLEX, 0.25, 255)
    
plt.figure(figsize=(12,12))
plt.imshow(img, cmap='gray')
